# %% [markdown]
# # Objective:
#
# We have to run through all the files inside the folder audios, and then transform it to wav.
#
# # Using ffmpeg
#
# Our project requires that we transform our `.mp3` audios to `.wav`.
#
# To do that, we chose the pydub lib to do the job. But, this library requires a few other things to work properly, one of them is the ffmpeg, a framework to decode, encode, transcode, mux, demux, stream, filter and play different type of files.
#
# ---
#
# ## Using it on Windows
# To install it is quite simple, you just need to [download the library](https://www.gyan.dev/ffmpeg/builds/), extract it somewhere easy to find, and add the `bin` folder to your `path`.

# %%
# I didn't manage to find a way to import local_utils, then I decided to add sys.path.insert for now. 
import sys
sys.path.insert(0, '../')

from local_utils import folder_utils
folder_utils.create_folder_if_doesnt_exist('../wav_audios')
# Out:
# ../wav_audios folder already exists.

# %%
import os
from os import path
from pydub import AudioSegment

# files                                                                         
src = "example-file.mp3"
dst = "../wav_audios/example-file.wav"

# convert wav to mp3                                                            
sound = AudioSegment.from_mp3(src)
sound.export(dst, format="wav")
# Out:
# <_io.BufferedRandom name='../wav_audios/example-file.wav'>

# %%
str('{}/{}').format("teste","teste")
# Out:
# 'teste/teste'

# %%
src_folder = "../audios"
dst_folder = "../wav_audios"

audio_files = folder_utils.get_files_in_folder(src_folder)

for file in audio_files:
    print(file)
    file_name = file.split(".mp3")[0]
    sound = AudioSegment.from_mp3(str("{}/{}").format(src_folder, file))
    dst_file = str("{}/{}.wav").format(dst_folder, file_name)
    print(dst_file)
    sound.export(dst_file, format="wav")
# Out:
# abiá-laranjeira_0.mp3
# ../wav_audios/abiá-laranjeira_0.wav
# abiá-laranjeira_1.mp3
# ../wav_audios/abiá-laranjeira_1.wav
# abiá-laranjeira_10.mp3
# ../wav_audios/abiá-laranjeira_10.wav
# abiá-laranjeira_11.mp3
# ../wav_audios/abiá-laranjeira_11.wav
# abiá-laranjeira_12.mp3
# ../wav_audios/abiá-laranjeira_12.wav
# abiá-laranjeira_13.mp3
# ../wav_audios/abiá-laranjeira_13.wav
# abiá-laranjeira_14.mp3
# ../wav_audios/abiá-laranjeira_14.wav
# abiá-laranjeira_15.mp3
# ../wav_audios/abiá-laranjeira_15.wav
# abiá-laranjeira_16.mp3
# ../wav_audios/abiá-laranjeira_16.wav
# abiá-laranjeira_17.mp3
# ../wav_audios/abiá-laranjeira_17.wav
# abiá-laranjeira_18.mp3
# ../wav_audios/abiá-laranjeira_18.wav
# abiá-laranjeira_19.mp3
# ../wav_audios/abiá-laranjeira_19.wav
# abiá-laranjeira_2.mp3
# ../wav_audios/abiá-laranjeira_2.wav
# abiá-laranjeira_3.mp3
# ../wav_audios/abiá-laranjeira_3.wav
# abiá-laranjeira_4.mp3
# ../wav_audios/abiá-laranjeira_4.wav
# abiá-laranjeira_5.mp3
# ../wav_audios/abiá-laranjeira_5.wav
# abiá-laranjeira_6.mp3
# ../wav_audios/abiá-laranjeira_6.wav
# abiá-laranjeira_7.mp3
# ../wav_audios/abiá-laranjeira_7.wav
# abiá-laranjeira_8.mp3
# ../wav_audios/abiá-laranjeira_8.wav
# abiá-laranjeira_9.mp3
# ../wav_audios/abiá-laranjeira_9.wav
# avoante_0.mp3
# ../wav_audios/avoante_0.wav
# avoante_1.mp3
# ../wav_audios/avoante_1.wav
# avoante_10.mp3
# ../wav_audios/avoante_10.wav
# avoante_2.mp3
# ../wav_audios/avoante_2.wav
# avoante_3.mp3
# ../wav_audios/avoante_3.wav
# avoante_4.mp3
# ../wav_audios/avoante_4.wav
# avoante_5.mp3
# ../wav_audios/avoante_5.wav
# avoante_6.mp3
# ../wav_audios/avoante_6.wav
# avoante_7.mp3
# ../wav_audios/avoante_7.wav
# avoante_8.mp3
# ../wav_audios/avoante_8.wav
# avoante_9.mp3
# ../wav_audios/avoante_9.wav
# caboclinho-de-barriga-preta_0.mp3
# ../wav_audios/caboclinho-de-barriga-preta_0.wav
# caboclinho-de-barriga-preta_1.mp3
# ../wav_audios/caboclinho-de-barriga-preta_1.wav
# caboclinho-de-barriga-preta_2.mp3
# ../wav_audios/caboclinho-de-barriga-preta_2.wav
# caboclinho-de-barriga-preta_3.mp3
# ../wav_audios/caboclinho-de-barriga-preta_3.wav
# caboclinho-de-barriga-preta_4.mp3
# ../wav_audios/caboclinho-de-barriga-preta_4.wav
# caboclinho-de-barriga-preta_5.mp3
# ../wav_audios/caboclinho-de-barriga-preta_5.wav
# caboclinho-de-barriga-preta_6.mp3
# ../wav_audios/caboclinho-de-barriga-preta_6.wav
# caboclinho-de-barriga-preta_7.mp3
# ../wav_audios/caboclinho-de-barriga-preta_7.wav
# caboclinho-de-barriga-preta_8.mp3
# ../wav_audios/caboclinho-de-barriga-preta_8.wav
# caboclinho-de-barriga-preta_9.mp3
# ../wav_audios/caboclinho-de-barriga-preta_9.wav
# canário-da-terra_0.mp3
# ../wav_audios/canário-da-terra_0.wav
# canário-da-terra_1.mp3
# ../wav_audios/canário-da-terra_1.wav
# canário-da-terra_10.mp3
# ../wav_audios/canário-da-terra_10.wav
# canário-da-terra_11.mp3
# ../wav_audios/canário-da-terra_11.wav
# canário-da-terra_12.mp3
# ../wav_audios/canário-da-terra_12.wav
# canário-da-terra_13.mp3
# ../wav_audios/canário-da-terra_13.wav
# canário-da-terra_14.mp3
# ../wav_audios/canário-da-terra_14.wav
# canário-da-terra_15.mp3
# ../wav_audios/canário-da-terra_15.wav
# canário-da-terra_16.mp3
# ../wav_audios/canário-da-terra_16.wav
# canário-da-terra_17.mp3
# ../wav_audios/canário-da-terra_17.wav
# canário-da-terra_18.mp3
# ../wav_audios/canário-da-terra_18.wav
# canário-da-terra_19.mp3
# ../wav_audios/canário-da-terra_19.wav
# canário-da-terra_2.mp3
# ../wav_audios/canário-da-terra_2.wav
# canário-da-terra_3.mp3
# ../wav_audios/canário-da-terra_3.wav
# canário-da-terra_4.mp3
# ../wav_audios/canário-da-terra_4.wav
# canário-da-terra_5.mp3
# ../wav_audios/canário-da-terra_5.wav
# canário-da-terra_6.mp3
# ../wav_audios/canário-da-terra_6.wav
# canário-da-terra_7.mp3
# ../wav_audios/canário-da-terra_7.wav
# canário-da-terra_8.mp3
# ../wav_audios/canário-da-terra_8.wav
# canário-da-terra_9.mp3
# ../wav_audios/canário-da-terra_9.wav
# coruja-listrada_0.mp3
# ../wav_audios/coruja-listrada_0.wav
# ../wav_audios/quete-do-sul_14.wav
# quete-do-sul_15.mp3
# ../wav_audios/quete-do-sul_15.wav
# quete-do-sul_16.mp3
# ../wav_audios/quete-do-sul_16.wav
# quete-do-sul_17.mp3
# ../wav_audios/quete-do-sul_17.wav
# quete-do-sul_18.mp3
# ../wav_audios/quete-do-sul_18.wav
# quete-do-sul_19.mp3
# ../wav_audios/quete-do-sul_19.wav
# quete-do-sul_2.mp3
# ../wav_audios/quete-do-sul_2.wav
# quete-do-sul_3.mp3
# ../wav_audios/quete-do-sul_3.wav
# quete-do-sul_4.mp3
# ../wav_audios/quete-do-sul_4.wav
# quete-do-sul_5.mp3
# ../wav_audios/quete-do-sul_5.wav
# quete-do-sul_6.mp3
# ../wav_audios/quete-do-sul_6.wav
# quete-do-sul_7.mp3
# ../wav_audios/quete-do-sul_7.wav
# quete-do-sul_8.mp3
# ../wav_audios/quete-do-sul_8.wav
# quete-do-sul_9.mp3
# ../wav_audios/quete-do-sul_9.wav
# urucuá-variado_0.mp3
# ../wav_audios/urucuá-variado_0.wav
# urucuá-variado_1.mp3
# ../wav_audios/urucuá-variado_1.wav
# urucuá-variado_10.mp3
# ../wav_audios/urucuá-variado_10.wav
# urucuá-variado_11.mp3
# ../wav_audios/urucuá-variado_11.wav
# urucuá-variado_12.mp3
# ../wav_audios/urucuá-variado_12.wav
# urucuá-variado_13.mp3
# ../wav_audios/urucuá-variado_13.wav
# urucuá-variado_14.mp3
# ../wav_audios/urucuá-variado_14.wav
# urucuá-variado_15.mp3
# ../wav_audios/urucuá-variado_15.wav
# urucuá-variado_16.mp3
# ../wav_audios/urucuá-variado_16.wav
# urucuá-variado_17.mp3
# ../wav_audios/urucuá-variado_17.wav
# urucuá-variado_18.mp3
# ../wav_audios/urucuá-variado_18.wav
# urucuá-variado_19.mp3
# ../wav_audios/urucuá-variado_19.wav
# urucuá-variado_2.mp3
# ../wav_audios/urucuá-variado_2.wav
# urucuá-variado_3.mp3
# ../wav_audios/urucuá-variado_3.wav
# urucuá-variado_4.mp3
# ../wav_audios/urucuá-variado_4.wav
# urucuá-variado_5.mp3
# ../wav_audios/urucuá-variado_5.wav
# urucuá-variado_6.mp3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-b3897fbd68c5> in <module>
#       7     print(file)
#       8     file_name = file.split(".mp3")[0]
# ----> 9     sound = AudioSegment.from_mp3(str("{}/{}").format(src_folder, file))
#      10     dst_file = str("{}/{}.wav").format(dst_folder, file_name)
#      11     print(dst_file)
#
# ~\anaconda3\envs\studying\lib\site-packages\pydub\audio_segment.py in from_mp3(cls, file, parameters)
#     794     @classmethod
#     795     def from_mp3(cls, file, parameters=None):
# --> 796         return cls.from_file(file, 'mp3', parameters=parameters)
#     797
#     798     @classmethod
#
# ~\anaconda3\envs\studying\lib\site-packages\pydub\audio_segment.py in from_file(cls, file, format, codec, parameters, start_second, duration, **kwargs)
#     732             # This is a workaround for some ffprobe versions that always say
#     733             # that mp3/mp4/aac/webm/ogg files contain fltp samples
# --> 734             audio_codec = audio_streams[0].get('codec_name')
#     735             if (audio_streams[0].get('sample_fmt') == 'fltp' and
#     736                     audio_codec in ['mp3', 'mp4', 'aac', 'webm', 'ogg']):
#
# IndexError: list index out of range
